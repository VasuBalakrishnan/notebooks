# %% [markdown]
# # Covid Data Analysis

# %%
from datetime import date as dt, timedelta
import os
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
fips_lookup_file = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv'
fips_lookup_df = pd.read_csv(fips_lookup_file)
column_map = {
    'Province/State': 'Province_State',
    'Country/Region': 'Country_Region',
    'Last Update': 'Last_Update',
    'Latitude': 'Lat',
    'Longitude': 'Long_'
}

# %%
data_path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/'
start_date = dt(2020, 1, 21)
end_date = dt.today()

# %%
covid_df = pd.DataFrame()
for date in pd.date_range(start_date, end_date):
    file = os.path.join(data_path, f'{date:%m-%d-%Y}.csv')
    try:
        temp_df = pd.read_csv(file)
        temp_df.rename(columns=column_map, inplace=True)
        temp_df['date'] = date
        covid_df = pd.concat([covid_df, temp_df])
    except:
        print(f'{file} not found')
        pass
# Out:
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-21-2020.csv not found
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv not found

# %%
grouped_df = covid_df.groupby('Combined_Key')
covid_df['Confirmed_Rate'] = grouped_df['Confirmed'].pct_change()
covid_df['Death_Rate'] = grouped_df['Deaths'].pct_change()
covid_df['Recovery_Rate'] = grouped_df['Recovered'].pct_change()

# %%
covid_us_df = covid_df[covid_df['Country_Region'] == 'US']

# %%
latest = covid_df['date'].max()
latest_covid_df = covid_df[covid_df['date'] == latest]
latest_covid_us_df = latest_covid_df[latest_covid_df['Country_Region'] == 'US']

# %%
output_cols = ['Combined_Key', 'Confirmed', 'Deaths', 'Recovered', 'Confirmed_Rate', 'Death_Rate', 'Recovery_Rate', 'Lat', 'Long_']
ts_cols = ['date'] + output_cols

# %% [markdown]
# ## Top Hotspots in US

# %%
top_hotspots_df = latest_covid_us_df.sort_values('Confirmed', ascending=False)[:15]
top_hotspots_df[output_cols]
# Out:
#                         Combined_Key  Confirmed  Deaths  Recovered  \
# 1636     New York City, New York, US    72181.0  3485.0        0.0
# 1618            Nassau, New York, US    15616.0   162.0        0.0
# 2441       Westchester, New York, US    14294.0   211.0        0.0
# 2146           Suffolk, New York, US    14185.0   199.0        0.0
# 513               Cook, Illinois, US     8728.0   209.0        0.0
# 2419               Wayne,Michigan,US     8270.0   346.0        0.0
# 153           Bergen, New Jersey, US     6862.0   200.0        0.0
# 1347     Los Angeles, California, US     6377.0   147.0        0.0
# 1944          Rockland, New York, US     5703.0   119.0        0.0
# 1706          Orleans, Louisiana, US     4565.0   171.0        0.0
# 716            Essex, New Jersey, US     4493.0   186.0        0.0
# 1514         Miami-Dade, Florida, US     4481.0    37.0        0.0
# 1031          Hudson, New Jersey, US     4395.0    92.0        0.0
# 1755         Passaic, New Jersey, US     3756.0    53.0        0.0
# 1789  Philadelphia, Pennsylvania, US     3728.0    45.0        0.0
#
#       Confirmed_Rate  Death_Rate  Recovery_Rate        Lat       Long_
# 1636        0.068541    0.544770            NaN  40.767273  -73.971526
# 1618        0.084595    0.000000            NaN  40.740665  -73.589419
# 2441        0.041609    2.149254            NaN  41.162784  -73.757417
# 2146        0.080433    0.137143            NaN  40.883201  -72.801217
# 513         0.086383    0.123656            NaN  41.841448  -87.816588
# 2419        0.100027    0.180887            NaN  42.278056  -83.378611
# 153         0.109100    0.058201            NaN  40.960109  -74.071643
# 1347        0.070865    0.113636            NaN  34.308284 -118.228241
# 1944        0.070785    0.724638            NaN  41.150279  -74.025605
# 1706        0.122725    0.062112            NaN  30.069720  -89.926603
# 716         0.100686    0.081395            NaN  40.786813  -74.246580
# 1514        0.080801    0.193548            NaN  25.611236  -80.551706
# 1031        0.120031    0.057471            NaN  40.737662  -74.075157
# 1755        0.163929    0.261905            NaN  41.032386  -74.299541
# 1789        0.169019    0.607143            NaN  40.003385  -75.137927

# %%
fig = go.Figure()

# for place in places:
fig.add_trace(go.Scattergeo(
        locationmode='USA-states',
        lat = latest_covid_us_df['Lat'],
        lon = latest_covid_us_df['Long_'],
        text = latest_covid_us_df['Combined_Key'],
        marker = dict(
            size=latest_covid_us_df['Confirmed']/100,
            sizemode='area'
        ),
        name='Confirmed'))
fig.update_layout(
    geo = dict(
        scope = 'usa'
    ),
    template='ggplot2')
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_583.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Top Hotspots Global

# %%
latest_covid_df.sort_values('Confirmed', ascending=False)[:15][output_cols]
# Out:
#                      Combined_Key  Confirmed   Deaths  Recovered  \
# 2781                        Spain   136675.0  13341.0    40437.0
# 2709                        Italy   132547.0  16523.0    22837.0
# 2690                      Germany   103374.0   1810.0    28700.0
# 2686                       France    98010.0   8911.0    17250.0
# 1636  New York City, New York, US    72181.0   3485.0        0.0
# 2575                 Hubei, China    67803.0   3212.0    64014.0
# 2705                         Iran    60500.0   3739.0    24236.0
# 2799               United Kingdom    51608.0   5373.0      135.0
# 2795                       Turkey    30217.0    649.0     1326.0
# 2786                  Switzerland    21657.0    765.0     8056.0
# 2643                      Belgium    20814.0   1632.0     3986.0
# 2745                  Netherlands    18803.0   1867.0      250.0
# 1618         Nassau, New York, US    15616.0    162.0        0.0
# 2441    Westchester, New York, US    14294.0    211.0        0.0
# 2146        Suffolk, New York, US    14185.0    199.0        0.0
#
#       Confirmed_Rate  Death_Rate  Recovery_Rate
# 2781        0.038201    0.055375       0.061896
# 2709        0.027910    0.040033       0.046848
# 2690        0.032470    0.142677       0.000000
# 2686        0.055699    0.103120       0.065933
# 1636        0.068541    0.544770            NaN
# 2575        0.000000    0.000623       0.001079
# 2705        0.039055    0.037746       0.228010
# 2799        0.079530    0.088974       0.000000
# 2795        0.116295    0.130662       0.272553
# 2786        0.026398    0.069930       0.255807
# 2643        0.057031    0.127851       0.062650
# 2745        0.053330    0.057191       0.000000
# 1618        0.084595    0.000000            NaN
# 2441        0.041609    2.149254            NaN
# 2146        0.080433    0.137143            NaN

# %% [markdown]
# ## Top Hotspots New York

# %%
latest_covid_df[latest_covid_df['Province_State'] == 'New York'].sort_values('Confirmed', ascending=False)[:15][output_cols]
# Out:
#                      Combined_Key  Confirmed  Deaths  Recovered  \
# 1636  New York City, New York, US    72181.0  3485.0        0.0
# 1618         Nassau, New York, US    15616.0   162.0        0.0
# 2441    Westchester, New York, US    14294.0   211.0        0.0
# 2146        Suffolk, New York, US    14185.0   199.0        0.0
# 1944       Rockland, New York, US     5703.0   119.0        0.0
# 1700         Orange, New York, US     3533.0    76.0        0.0
# 675        Dutchess, New York, US     1189.0     9.0        0.0
# 710            Erie, New York, US     1148.0    30.0        0.0
# 1554         Monroe, New York, US      574.0    26.0        0.0
# 2250         Ulster, New York, US      382.0     4.0        0.0
# 1693       Onondaga, New York, US      377.0     5.0        0.0
# 1875         Putnam, New York, US      345.0     7.0        0.0
# 24           Albany, New York, US      319.0     8.0        0.0
# 2150       Sullivan, New York, US      253.0     6.0        0.0
# 2003       Saratoga, New York, US      153.0     4.0        0.0
#
#       Confirmed_Rate  Death_Rate  Recovery_Rate
# 1636        0.068541    0.544770            NaN
# 1618        0.084595    0.000000            NaN
# 2441        0.041609    2.149254            NaN
# 2146        0.080433    0.137143            NaN
# 1944        0.070785    0.724638            NaN
# 1700        0.108566    0.433962            NaN
# 675         0.103993    0.125000            NaN
# 710         0.084042    0.111111            NaN
# 1554        0.047445    0.368421            NaN
# 2250        0.067039    0.000000            NaN
# 1693        0.035714    0.000000            NaN
# 1875        0.098726    0.000000            NaN
# 24          0.045902    0.000000            NaN
# 2150        0.310881    0.200000            NaN
# 2003        0.020000    3.000000            NaN

# %% [markdown]
# ## Top Counties in each State

# %%
states = ['New York', 'Washington', 'Texas']
top_counties_df = (latest_covid_us_df
                       .assign(rank=latest_covid_us_df
                                        .sort_values(['Confirmed'], ascending=False)
                                        .groupby('Province_State')
                                        .cumcount() + 1)
                       .query('rank <= 5')
                       .sort_values(['Province_State', 'rank'])[['Province_State'] + output_cols]
)
top_counties_df[top_counties_df['Province_State'].isin(states)]
# Out:
#      Province_State                 Combined_Key  Confirmed  Deaths  \
# 1636       New York  New York City, New York, US    72181.0  3485.0
# 1618       New York         Nassau, New York, US    15616.0   162.0
# 2441       New York    Westchester, New York, US    14294.0   211.0
# 2146       New York        Suffolk, New York, US    14185.0   199.0
# 1944       New York       Rockland, New York, US     5703.0   119.0
# 956           Texas              Harris,Texas,US     1809.0    22.0
# 583           Texas            Dallas, Texas, US     1155.0    18.0
# 2228          Texas            Travis, Texas, US      502.0     6.0
# 2184          Texas           Tarrant, Texas, US      452.0    13.0
# 162           Texas             Bexar, Texas, US      410.0    12.0
# 1181     Washington         King, Washington, US     3331.0   222.0
# 2072     Washington    Snohomish, Washington, US     1603.0    58.0
# 1800     Washington       Pierce, Washington, US      717.0    12.0
# 2292     Washington   Unassigned, Washington, US      648.0     0.0
# 2517     Washington       Yakima, Washington, US      363.0    12.0
#
#       Recovered  Confirmed_Rate  Death_Rate  Recovery_Rate
# 1636        0.0        0.068541    0.544770            NaN
# 1618        0.0        0.084595    0.000000            NaN
# 2441        0.0        0.041609    2.149254            NaN
# 2146        0.0        0.080433    0.137143            NaN
# 1944        0.0        0.070785    0.724638            NaN
# 956         0.0        0.296774    0.100000            NaN
# 583         0.0        0.038669    0.000000            NaN
# 2228        0.0        0.037190    0.000000            NaN
# 2184        0.0        0.081340    0.181818            NaN
# 162         0.0        0.067708    0.090909            NaN
# 1181        0.0        0.051784    0.067308            NaN
# 2072        0.0        0.028223    0.208333            NaN
# 1800        0.0        0.042151    0.200000            NaN
# 2292        0.0        0.215760         NaN            NaN
# 2517        0.0        0.113497    0.333333            NaN

# %% [markdown]
# ## Hotspot Analysis

# %%
top_hotspots =  top_hotspots_df['Combined_Key'].tolist()

# %% [markdown]
# ### Growth Rate amongst hotspots

# %%
fig = go.Figure()
for place in top_hotspots[:5]:
    place_df = covid_us_df[covid_us_df['Combined_Key'] == place]
    fig.add_trace(go.Scatter(x=place_df['date'], y=place_df['Confirmed_Rate'], mode='lines', name=place))
    
fig.update_layout(
    autosize=False,
    template='ggplot2')
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_613.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Confirmed Cases amongst hotspots

# %%
fig = go.Figure()
for place in top_hotspots[:5]:
    place_df = covid_us_df[covid_us_df['Combined_Key'] == place]
    fig.add_trace(go.Scatter(x=place_df['date'], y=place_df['Confirmed'], mode='lines', name=place))

    
fig.update_layout(
    autosize=False,
    template='ggplot2')
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_611.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
